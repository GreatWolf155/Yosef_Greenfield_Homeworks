# %%
import numpy as np

# %% [markdown]
# # Question 1
# Given d = np.arange(12).reshape(3,4) — what does d.size return?
# size = total number of elements

# %%
d = np.arange(12).reshape(3,4)
d.size # returns 12, the total number of numbers in the array
# Out:
# 12

# %% [markdown]
# # Question 2
# Given f = np.array([1, 2, 3]) — what does f.astype(float) produce?
# astype converts element type
# array([?, ?, ?])

# %%
f = np.array([1, 2, 3])
f.astype(float) # produces the same array, but instead of integer dtypes, the numbers are now dtype float
# Out:
# array([1., 2., 3.])

# %% [markdown]
# # Question 3
# Given a = np.array([[1,2,3],[4,5,6]]) — what does a.shape return?
# shape is (rows, cols)
# (?, ?)

# %%
a = np.array([[1,2,3],[4,5,6]])
a.shape # returns tuple (2, 3), for the dimensions of the array; 2 items, with 3 numbers in each of them
# Out:
# (2, 3)

# %% [markdown]
# # Question 4
# Given e = np.array([1.0, 2.0, 3.0]) — what does e.dtype return?
# dtype describes the element type
# dtype('?')

# %%
e = np.array([1.0, 2.0, 3.0])
e.dtype # because we called each number with a decimal, the numbers will be of dtype float
# Out:
# dtype('float64')

# %% [markdown]
# # Question 5
# Given c = np.ones((2, 3, 4)) — what does c.ndim return?
# ndim = number of axes
# ?

# %%
c = np.ones((2, 3, 4))
c.ndim # returns 3, because the array is a 3 dimensional array
# Out:
# 3

# %% [markdown]
# # Question 6
# Given b = np.zeros((4, 3)) — what does len(b) return?
# len() returns the size of the first axis
# ?

# %%
b = np.zeros((4, 3))
len(b) # returns 4, because len will only check the first axis, or the number of rows
# Out:
# 4
